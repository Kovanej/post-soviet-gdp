# %%
import matplotlib.pyplot as plt
import pandas as pd
import streamlit as st

# %%
df = pd.read_csv("data/gdp_data.csv")

# %%
df
# Out:
#                                         Country Name Country Code  \
# 0                                            Armenia          ARM
# 1                                            Armenia          ARM
# 2                                            Armenia          ARM
# 3                                            Armenia          ARM
# 4                                         Azerbaijan          AZE
# ..                                               ...          ...
# 60                                               NaN          NaN
# 61                                               NaN          NaN
# 62                                               NaN          NaN
# 63  Data from database: World Development Indicators          NaN
# 64                          Last Updated: 07/01/2025          NaN
#
#                                       Series Name        Series Code  \
# 0                               GDP (current US$)     NY.GDP.MKTP.CD
# ...
